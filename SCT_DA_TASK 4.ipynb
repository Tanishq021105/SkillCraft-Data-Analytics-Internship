# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('train.csv')
df.head()
df.info()
df.isnull().sum()
df = df.dropna()
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.describe()
print(df.columns)
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar', figsize=(8,5))

plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.xticks(rotation=0)

plt.show()
region_sales = df.groupby('Region')['Sales'].sum()

region_sales.plot(kind='bar', figsize=(8,5))

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.xticks(rotation=0)

plt.show()

top_subcategory = df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).head(10)

top_subcategory.plot(kind='bar', figsize=(10,5))

plt.title("Top 10 Sub-Categories by Sales")
plt.xlabel("Sub-Category")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.show()

segment_sales = df.groupby('Segment')['Sales'].sum()

segment_sales.plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))

plt.title("Sales by Segment")

plt.ylabel('')

plt.show()

ship_sales = df.groupby('Ship Mode')['Sales'].sum()

ship_sales.plot(kind='bar', figsize=(8,5))

plt.title("Sales by Ship Mode")
plt.xlabel("Ship Mode")
plt.ylabel("Total Sales")

plt.xticks(rotation=15)

plt.show()

plt.figure(figsize=(8,5))

sns.histplot(df['Sales'], bins=30)

plt.title("Sales Distribution")

plt.show()

plt.figure(figsize=(8,5))

sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.show()

top_states = df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10)

top_states.plot(kind='bar', figsize=(10,5))

plt.title("Top 10 States by Sales")
plt.xlabel("State")
plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.show()

df.to_csv('cleaned_superstore_data.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# **1. Sales by Category Chart**
# ### Insights
#
# **✅ Highest:**
# Technology category generated the highest sales.
#
# **✅ Lowest:**
# Office Supplies/Furniture generated comparatively lower sales.
#
# **✅ Business Meaning:**
# This indicates that customers purchase Technology products more frequently, making it the strongest revenue-generating category for the business.

# %% [markdown]
# **2. Sales by Region Chart**
# ### **Insights**
#
#
# ✅ **Highest:**
# The Western region recorded the highest sales performance.
#
# ✅ **Lowest:**
# The Southern region showed the lowest sales.
#
# ✅ **Business Meaning:**
# This indicates stronger customer demand and business performance in the Western region compared to other regions.

# %% [markdown]
# **3. Top 10 Sub-Category Chart**
#
# **Insights**
#
# ✅ **Highest:**
# Some sub-categories like Phones/Chairs/Storage generated the highest sales.
#
# ✅ **Lowest:**
# Lower-ranked sub-categories contributed comparatively less revenue.
#
# ✅ **Business Meaning:**
# A few products dominate overall sales, showing that customer demand is concentrated on specific product types.

# %% [markdown]
# **4. Sales by Segment Pie Chart**
# ### **Insights**
#
# ✅ **Highest:**
# The Consumer segment contributed the highest percentage of total sales.
#
# ✅ **Lowest:**
# The Home Office segment contributed the lowest sales.
#
# ✅ **Business Meaning:**
# The business relies heavily on consumer customers, making them the primary target audience for revenue generation.

# %% [markdown]
# **5. Sales by Ship Mode Chart**
#
# ### Insights
#
# ✅** Highest:**
# Standard Class shipping mode was used the most.
#
# ✅ **Lowest:**
# Same Day shipping mode was used the least.
#
# ✅ **Business Meaning:**
# Customers appear to prefer economical shipping methods over faster premium delivery options.

# %% [markdown]
# **6. Sales Distribution Histogram**
#
# ### Insights
#
# ✅ **Highest:**
# Most sales values are concentrated in lower ranges.
#
# ✅ **Lowest:**
# Very high sales transactions occur less frequently.
#
# ✅ **Business Meaning:**
# The business experiences a large number of smaller transactions and fewer high-value purchases.

# %% [markdown]
# **7. Correlation Heatmap**
#
# ### Insights
#
# ✅ **Highest:**
# Some numerical variables show positive correlation with sales.
#
# ✅ **Lowest:**
# Weak correlations exist between unrelated variables.
#
# ✅ **Business Meaning:**
# Certain factors may influence sales performance more strongly than others, helping identify important business drivers.

# %% [markdown]
# **8. Top States by Sales Chart**
#
# ### Insights
#
# ✅ **Highest:**
# States like California and New York generated the highest sales.
#
# ✅ **Lowest:**
# Some states contributed comparatively lower revenue.
#
# ✅ **Business Meaning:**
# Sales performance varies significantly across states, indicating stronger markets in specific locations.

# %% [markdown]
# **`# Recommendations`**
#
# 1. Increase focus on high-performing categories like Technology.
#
# 2. Improve sales and marketing strategies in low-performing regions.
#
# 3. Focus more on Consumer segment customers to maximize revenue.
#
# 4. Optimize Standard Class shipping services for better customer satisfaction.
#
# 5. Promote top-selling products more aggressively to increase overall sales.
